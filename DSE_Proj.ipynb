# %% [markdown]
# <a href="https://colab.research.google.com/github/YashBurman1/Foundations-in-MLP/blob/main/DSE_Proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %% [markdown]
# # EDA

# %%
data.dtypes
# Out:
# id                             int64
# Time_spent_Alone             float64
# Stage_fear                    object
# Social_event_attendance      float64
# Going_outside                float64
# Drained_after_socializing     object
# Friends_circle_size          float64
# Post_frequency               float64
# Personality                   object
# dtype: object

# %%
data.describe()
# Out:
#                  id  Time_spent_Alone  Social_event_attendance  Going_outside  \
# count  18524.000000      17334.000000             17344.000000   17058.000000
# mean    9261.500000          3.137764                 5.265106       4.044319
# std     5347.562529          3.003786                 2.753359       2.062580
# min        0.000000          0.000000                 0.000000       0.000000
# 25%     4630.750000          1.000000                 3.000000       3.000000
# 50%     9261.500000          2.000000                 5.000000       4.000000
# 75%    13892.250000          4.000000                 8.000000       6.000000
# max    18523.000000         11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency
# count         17470.000000    17260.000000
# mean              7.996737        4.982097
# std               4.223484        2.879139
# min               0.000000        0.000000
# 25%               5.000000        3.000000
# ...

# %%
# data['Social_event_attendance'].hist(bins=10)
# data['Time_spent_Alone'].hist(bins=10,alpha=0.5)
# data['Post_frequency'].hist(bins=10,alpha=0.5)
plt.scatter(data["Post_frequency"], data["Social_event_attendance"])

# %%
data.drop(columns=["Stage_fear","Drained_after_socializing","Personality","id"]).corr()
# Out:
#                          Time_spent_Alone  Social_event_attendance  \
# Time_spent_Alone                 1.000000                -0.628806
# Social_event_attendance         -0.628806                 1.000000
# Going_outside                   -0.640884                 0.585224
# Friends_circle_size             -0.598014                 0.566675
# Post_frequency                  -0.611544                 0.566679
#
#                          Going_outside  Friends_circle_size  Post_frequency
# Time_spent_Alone             -0.640884            -0.598014       -0.611544
# Social_event_attendance       0.585224             0.566675        0.566679
# Going_outside                 1.000000             0.549864        0.579305
# Friends_circle_size           0.549864             1.000000        0.522272
# Post_frequency                0.579305             0.522272        1.000000

# %% [markdown]
# # Preprocessing

# %%
X = data.drop(columns=["Personality"])
y = data["Personality"]

X_train,X_test,y_train,y_test = train_test_split(X,y, train_size=0.8,random_state=66)

# %%
# Out:
# id                              0
# Time_spent_Alone              955
# Stage_fear                   1497
# Social_event_attendance       932
# Going_outside                1181
# Drained_after_socializing     926
# Friends_circle_size           828
# Post_frequency               1039
# dtype: int64

# %% [markdown]
# # To Do
# 1. Make dummy variables for "Stage_fear", "Drained_after_socializing", "Personality"
# 2. Take care of empty values: *Imputation*
